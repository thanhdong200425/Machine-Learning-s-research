# %% [markdown]
# ## Remember: Decision Tree Regression isn't the best model to train with dataset which only has one feature

# %% [markdown]
# # DataPreprocessing phase

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Position_Salaries.csv')
X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# # Training the Decision Tree Regression model on the whole dataset

# %% [markdown]
# ### Remember things
# - For decision tree and random forest regressions, you don't have to apply feature scalling, because in these regressions, they only care about whether a value is above or below a threshold, not how big the difference is

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# # Predicting a new result

# %%
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %% [markdown]
# # Visualising the Decision Tre Regression results (higher resolution)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
print(X_grid)

# %%
X_grid = X_grid.reshape(-1, 1)
print(X_grid)

# %%
plt.scatter(X, y, color='red')
plt.plot(X_grid, regressor.predict(X_grid), color='blue')
plt.title('Truth or Bluff (Decision Tree Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
